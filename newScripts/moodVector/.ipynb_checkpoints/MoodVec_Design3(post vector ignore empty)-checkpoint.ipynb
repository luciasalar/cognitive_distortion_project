# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import csv
from datetime import datetime
# Out:
# /home/lucia/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# * Mood vector Design 1: for each day, if negative_count > positive_count or negative_count > neutral_count or neative_count > mix_count, assign negative to that day; if positive_count > negative_count or positive_count > neutral_count or positive_count > mix_count, assign positive to that day; if mix_count >= positive_count or mix_count >= negative_count or negative_count == positive_count, assign mix to that day; if neutral_count >= positive_count or neutral_count >= negative_count or neutral_count > mix_count, assign neutral to that day.

# %%
#path = '/Users/lucia/phd_work/cognitive_distortion/'
path = '/home/lucia/phd_work/mypersonality_data/cognitive_distortion/'
time = pd.read_csv(path + '/data/important_data/twoM_newLabels.csv')
ids = pd.read_csv(path + '/data/important_data/Id80PerRetained.csv')
time  = time[['text','id','negative_ny','userid','time','time_diff']]
time.shape
# Out:
# (4099, 6)

# %%
ids2 = ids[['userid']]
time = pd.merge(ids2, time, how = 'left', on = 'userid' )
time.shape
# Out:
# (4086, 6)

# %%
#select date
time['time'] = time['time'].apply(lambda x: x.split()[0])
time[0:5]
# Out:
#                              userid  \
# 0  009d96a823b6f6c085c092fb177491f6
# 1  009d96a823b6f6c085c092fb177491f6
# 2  009d96a823b6f6c085c092fb177491f6
# 3  009d96a823b6f6c085c092fb177491f6
# 4  009d96a823b6f6c085c092fb177491f6
#
#                                                 text   id  negative_ny  \
# 0  Happy mothers day to all the privileged beauti...  950            2
# 1  In honor of Mother's Day, we are trying to see...  948            4
# 2  What would your liqour do? If it could, it wou...  949            2
# 3  War is about who's left not who's right.... be...  946            2
# 4  Loving the fact my babie made me breakfast mmm...  942            2
#
#          time  time_diff
# 0  08/05/2011          4
# 1  05/05/2011          7
# 2  05/05/2011          7
# 3  04/05/2011          8
# 4  01/05/2011         11

# %%
#convert to time series
# time['time'] = time['time'].apply(lambda x: parser.parse(x))
# time['time'] = time['time'].apply(lambda x: datetime.strptime(x, '%d %b %Y'))
time['time'] = time['time'].apply(lambda x: datetime.strptime(x, '%d/%m/%Y'))
time['time'][1:10]
# Out:
# 1   2011-05-05
# 2   2011-05-05
# 3   2011-05-04
# 4   2011-05-01
# 5   2011-04-28
# 6   2011-04-25
# 7   2011-04-20
# 8   2011-04-20
# 9   2011-04-19
# Name: time, dtype: datetime64[ns]

# %%
#sort values according to userid, time and valence
time = time.sort_values(by=['userid','time_diff','negative_ny'],  ascending=False)
len(time['userid'].unique())
# Out:
# 74

# %%
def getTransitions(ValenceObject):
    negaTran = 0
    posiTran = 0
    mixTran = 0
    neuTran = 0
    PosAndNeg = 0
    MixAndPos = 0
    MixAndNeg = 0
    MixAndNeu = 0    
    NeuAndPos = 0
    NeuAndNeg = 0
    preValence = 0
    for valence in ValenceObject:
    #these are self transition states
        if valence == 1 and preValence == 1:
            negaTran = negaTran + 1
        elif valence == 2 and preValence == 2:
            posiTran = posiTran + 1
        elif valence == 3 and preValence == 3:
            mixTran = mixTran + 1
        elif valence == 4 and preValence == 4:
            neuTran = neuTran + 1
    #positive and negative transition:
        if (valence == 1 and preValence == 2) or (valence == 2 and preValence == 1) :
            PosAndNeg = PosAndNeg + 1
    #mix and positive transition
        if (valence == 3 and preValence == 2) or (valence == 2 and preValence == 3) :
            MixAndPos = MixAndPos + 1
    #mix and negative transition
        if (valence == 3 and preValence == 1) or (valence == 1 and preValence == 3) :
            MixAndNeg = MixAndNeg + 1
    #mix and neutral transition
        if (valence == 3 and preValence == 4) or (valence == 4 and preValence == 3) :
            MixAndNeu = MixAndNeu + 1
    #neutral and postive transition
        if (valence == 4 and preValence == 2) or (valence == 2 and preValence == 4) :
            NeuAndPos = NeuAndPos + 1
    #neutral and negative transition 
        if (valence == 4 and preValence == 1) or (valence == 1 and preValence == 4) :
            NeuAndNeg = NeuAndNeg + 1      
        preValence = valence
    return [negaTran, posiTran, mixTran, neuTran, PosAndNeg, MixAndPos, MixAndNeg, MixAndNeu, NeuAndPos, NeuAndNeg]

# %%
def getValenceVector(df):
    valenceVec = {}
    valences =[]
    preUser = None
    for valence, day, user in zip(df['negative_ny'], df['time_diff'], df['userid']):
        #first case
        if preUser is None:
            valences = [valence]
            valenceVec[user] = valences
        elif user == preUser:
            valences.append(valence)
        else: 
            valences = [valence]
            valenceVec[user] = valences               
        preUser = user
    #valenceVec[preUser] = valences
    return valenceVec

valenceVec = getValenceVector(time)

# %%
i = 0
for item in valenceVec:
    print(item,valenceVec[item])
    i = i+1
print(i)
# Out:
# fbd681e79ebca2cd9509218403f23ec6 [2, 2, 2, 2, 2, 4, 2, 4, 2, 2, 4, 2, 2, 2, 2, 2, 1, 4, 2, 2, 1, 5, 1, 1, 2, 2, 1, 1, 1, 1, 2, 1, 2, 2, 2, 1, 2, 2, 1, 2]
# f8708568eff1535c85247b28dc126f9b [2, 2, 2, 1, 1, 4, 2, 4, 2, 1, 2, 2, 1, 1, 4, 2, 2, 2, 2, 1, 1, 1, 4, 4, 2, 1, 3, 2, 2, 2, 2, 2, 4, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 4, 2, 1, 4, 2, 1, 4, 4, 1, 4, 2, 1, 1, 4, 2, 2, 2, 1, 4, 2, 2, 1, 1, 1, 1, 2, 1, 2, 1, 1, 2, 1, 1, 2, 2, 1, 1, 2, 2, 2, 4, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 1, 1, 1, 1, 4, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 1, 1, 4, 1, 4, 2, 3, 2, 2, 4, 4, 4, 2, 1, 2, 2, 1, 1, 1, 2, 1, 1, 1, 1, 4, 2, 2, 1, 2, 2, 2, 1, 4, 2, 2, 2, 2, 1, 2, 2]
# f49956142aab2ad74decfd49a103c2f1 [4, 1, 1, 1, 1, 4, 4, 1, 4, 1, 2, 2, 4, 2, 4, 4, 1, 1, 1, 4, 2, 2, 1, 2, 2, 2, 1, 2, 4, 2, 2, 2, 2, 1, 2, 1, 4, 4, 1, 2, 4, 2, 2, 4, 1, 2, 2, 2, 2]
# f358b75c71d85c91ec0452c6114e3b15 [2, 2, 2, 2, 4, 2, 2, 1, 2, 2, 2, 1, 4, 2, 1, 3, 3, 3, 2, 2, 2, 1, 2, 2, 1, 1, 1, 1, 2, 2, 2, 2, 2,
 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 4, 2, 2, 1, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 1, 1, 1, 1, 1, 2, 2, 2, 2]
# 088bf0ed841bcc366475b3975eb1b9d2 [2, 4, 1, 1, 2, 2, 1, 2, 2, 2, 1, 2, 1, 2, 2, 1, 1, 1, 4, 1, 4, 2, 2, 2, 4, 2, 1, 2, 1, 1, 1, 4, 2, 1, 4, 2, 4, 4, 2, 4, 2]
# 0724fe854bd455061ba84efecdeff469 [2, 1, 2, 1, 2, 1, 4, 1, 4, 4, 4, 1, 4, 1, 1, 2, 1, 4, 4, 2, 2, 1, 2, 1, 1, 2, 1, 1, 4, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 1, 1, 1, 3, 2, 2, 4]
# 009d96a823b6f6c085c092fb177491f6 [1, 2, 1, 4, 1, 1, 2, 2, 2, 1, 1, 4, 2, 2, 2, 1, 1, 4, 4, 2, 2, 1, 1, 4, 2, 2, 4, 2, 3, 2, 1, 1, 1, 1, 1, 1, 2, 4, 2, 2, 2, 1, 2, 2, 4, 2, 2]
# 74

# %%
count = 0
negativeD = []
positiveD = []
neutralD = []
mixed = []
useridL = []
for userid in valenceVec:
    negativeD.append(valenceVec[userid].count(1))
    positiveD.append(valenceVec[userid].count(2))
    neutralD.append(valenceVec[userid].count(4))
    mixed.append(valenceVec[userid].count(3))
    useridL.append(userid)
    print('user {} has  {} negative days, {} positive days , {} neutral days and mix days {}'.format(userid, valenceVec[userid].count(1), valenceVec[userid].count(2), valenceVec[userid].count(4), valenceVec[userid].count(3)))
#     count += 1
#     if count == 5:
#         break
# Out:
# user fbd681e79ebca2cd9509218403f23ec6 has  11 negative days, 24 positive days , 4 neutral days and mix days 0
# user f8708568eff1535c85247b28dc126f9b has  49 negative days, 87 positive days , 22 neutral days and mix days 3
# user f49956142aab2ad74decfd49a103c2f1 has  15 negative days, 21 positive days , 13 neutral days and mix days 0
# user f358b75c71d85c91ec0452c6114e3b15 has  9 negative days, 25 positive days , 3 neutral days and mix days 3
# user ec3dc451b8a811f05ace158a0d76e32e has  14 negative days, 2 positive days , 8 neutral days and mix days 0
# user eaeabcfe25866f0455d349bae2450d88 has  11 negative days, 28 positive days , 6 neutral days and mix days 1
# user e9970fe8848e9505b52d414d81611de8 has  5 negative days, 17 positive days , 6 neutral days and mix days 2
# user e076953cd3fcf8927b8f21574c0890f3 has  10 negative days, 19 positive days , 10 neutral days and mix days 1
# user dcbe08425f5edef5e5c1053f21e83640 has  5 negative days, 15 positive days , 8 neutral days and mix days 0
# user db7f1b0130b2138e13b7bbca9cc63823 has  15 negative days, 19 positive days , 13 neutral days and mix days 0
# user d5380466e18422d7b2c2d54d57cbbde2 has  9 negative days, 15 positive days , 6 neutral days and mix days 2
# user cfb021cfbff46ffdb75c7dcafe7c2087 has  16 negative days, 19 positive days , 25 neutral days and mix days 2
# user cea00424ced413c108d878b1a14f3316 has  7 negative days, 17 positive days , 9 neutral days and mix days 0
# user cd86d1e6d68c3770eaec0db419dceb2f has  38 negative days, 32 positive days , 21 neutral days and mix days 2
# user 5f86969fe97dd82aba8a683fe7ce6460 has  9 negative days, 39 positive days , 8 neutral days and mix days 1
# user 5cc136477bfe3fcfe809dc451e4243ef has  21 negative days, 21 positive days , 27 neutral days and mix days 0
# user 5c31d7d80e78643cd5289acec0561d77 has  8 negative days, 6 positive days , 5 neutral days and mix days 1
# user 5b1eb32579450829ec8faab4d3472ffb has  4 negative days, 9 positive days , 6 neutral days and mix days 2
# user 57118d9a71e91b6568471ffbd7077415 has  4 negative days, 13 positive days , 4 neutral days and mix days 0
# user 55a72284594fdda49b22a6610b9b91d6 has  24 negative days, 25 positive days , 20 neutral days and mix days 3
# user 4d7ae0617845c6b30eb85b55a991f4c5 has  14 negative days, 17 positive days , 6 neutral days and mix days 4
# user 49fb9fce8f4dc022318b8cd432aad8b6 has  9 negative days, 21 positive days , 0 neutral days and mix days 0
# user 4908adae6cf09defb838925defcc5e61 has  26 negative days, 59 positive days , 24 neutral days and mix days 2
# user 4764518d32334248e6ebbf681a18fd0c has  37 negative days, 35 positive days , 21 neutral days and mix days 1
# user 41ef345410ba421410cb4d09c331aec3 has  9 negative days, 16 positive days , 9 neutral days and mix days 0
# user 4104c0b8700d519d1661c8a59b065363 has  12 negative days, 13 positive days , 14 neutral days and mix days 1
# user 3e6f69fc89da71e8237c717ac218677b has  12 negative days, 7 positive days , 3 neutral days and mix days 0
# user 3ac58ad39d81acfe169aadc4815effe6 has  25 negative days, 20 positive days , 14 neutral days and mix days 0
# user 39b2af957c2488970cb89c161b6bf94e has  50 negative days, 71 positive days , 15 neutral days and mix days 6
# user 30723e9e5ecfe6d20e5e67d1163e3965 has  10 negative days, 40 positive days , 35 neutral days and mix days 1
# user 2fba0f9dccc84f3516d8b553426af527 has  22 negative days, 20 positive days , 5 neutral days and mix days 2
# user 2dca898dfbdae6716a587adbfd99c542 has  17 negative days, 19 positive days , 12 neutral days and mix days 1
# user 2a9b90b41e9399bb331fef2582f657c3 has  107 negative days, 68 positive days , 27 neutral days and mix days 4
# user 29cda473b52e1c75fbfe958ed3aec565 has  2 negative days, 20 positive days , 8 neutral days and mix days 2
# user 2549774d68d7ccbcba069afb45c7e237 has  20 negative days, 19 positive days , 17 neutral days and mix days 1
# user 23cbbe03a89344129e1a6d8419a66d23 has  5 negative days, 27 positive days , 4 neutral days and mix days 1
# user 1e84bfe1c9bbd549913aad1bc57c8878 has  6 negative days, 18 positive days , 9 neutral days and mix days 1
# user 1c1a61d11a10f9fa967f250095792db3 has  7 negative days, 20 positive days , 8 neutral days and mix days 1
# user 193165601dfad67e79ef52b2caf9fd9e has  8 negative days, 11 positive days , 1 neutral days and mix days 2
# user 1789589a6d2bba0f09d768f8f3445be5 has  24 negative days, 13 positive days , 13 neutral days and mix days 1
# user 0e3fdb89c7706b13891170ab2a9017c7 has  6 negative days, 24 positive days , 5 neutral days and mix days 2
# user 0c5d06511ef79fba34da417e8c751fff has  10 negative days, 19 positive days , 3 neutral days and mix days 1
# user 0b12516100c16f779b152858619786ff has  20 negative days, 38 positive days , 3 neutral days and mix days 0
# user 088bf0ed841bcc366475b3975eb1b9d2 has  14 negative days, 18 positive days , 9 neutral days and mix days 0
# user 0724fe854bd455061ba84efecdeff469 has  19 negative days, 20 positive days , 9 neutral days and mix days 1
# user 009d96a823b6f6c085c092fb177491f6 has  17 negative days, 21 positive days , 8 neutral days and mix days 1

# %%
def getUserTransitions(valencVec):
    result = {}
    for item in valencVec:
        result[item] = getTransitions(valencVec[item])
#         print(result)
    return result
        
TransitionStates = getUserTransitions(valenceVec)

# %% [markdown]
# create table for statistics

# %%
df = pd.DataFrame(np.array(negativeD).reshape(74,1), columns=['NegativePosts'])
df['PositivePosts'] = positiveD
df['NeutralPosts'] = neutralD
df['MixedPosts'] = mixed
df['userid'] = useridL
df[1:5]
# Out:
#    NegativePosts  PositivePosts  NeutralPosts  MixedPosts  \
# 1             49             87            22           3
# 2             15             21            13           0
# 3              9             25             3           3
# 4             14              2             8           0
#
#                              userid
# 1  f8708568eff1535c85247b28dc126f9b
# 2  f49956142aab2ad74decfd49a103c2f1
# 3  f358b75c71d85c91ec0452c6114e3b15
# 4  ec3dc451b8a811f05ace158a0d76e32e

# %%
df.describe()
# Out:
#        NegativePosts  PositivePosts  NeutralPosts  MixedPosts
# count      74.000000      74.000000     74.000000   74.000000
# mean       16.337838      27.013514     10.243243    1.189189
# std        15.393716      21.620318      8.098386    1.677210
# min         0.000000       2.000000      0.000000    0.000000
# 25%         7.250000      17.000000      5.000000    0.000000
# 50%        12.000000      20.500000      8.000000    1.000000
# 75%        19.750000      26.750000     13.750000    2.000000
# max       107.000000     100.000000     39.000000   11.000000

# %%
#pickle
import pickle
with open(path + 'newScripts/moodVector/moodVectorsData/MoodVecDes3.pickle', 'wb') as handle:
    pickle.dump(valenceVec, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#write result as csv
#header = ['userid','vector']
with open(path + 'newScripts/moodVector/moodVectorsData/PostsValenceTransitions(noEmp).csv','w') as csv_file:
    writer = csv.writer(csv_file)
   # writer.writerow(i for i in header)
    writer.writerow(TransitionStates.keys())
    for row in zip(*TransitionStates.values()):
        writer.writerow(list(row))

# %%
#read csv file 
import pandas as pd
path = '/Users/lucia/phd_work/cognitive_distortion'
file = pd.read_csv(path + '/newScripts/moodVector/moodVectorsData/ValenceNoEmpty.csv')
file.columns = ['userid','negaTran', 'posiTran', 'mixTran', 'neuTran', 'PosAndNeg', 'MixAndPos', 'MixAndNeg', 'MixAndNeu', 'NeuAndPos', 'NeuAndNeg']
file[1:5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-08d8b0c06434> in <module>()
#       3 path = '/Users/lucia/phd_work/cognitive_distortion'
#       4 file = pd.read_csv(path + '/newScripts/moodVector/moodVectorsData/ValenceNoEmpty.csv')
# ----> 5 file.columns = ['negaTran', 'posiTran', 'mixTran', 'neuTran', 'PosAndNeg', 'MixAndPos', 'MixAndNeg', 'MixAndNeu', 'NeuAndPos', 'NeuAndNeg']
#       6 file[1:5]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    2981         try:
#    2982             object.__getattribute__(self, name)
# -> 2983             return object.__setattr__(self, name, value)
#    2984         except AttributeError:
#    2985             pass
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.AxisProperty.__set__ (pandas/_libs/lib.c:45103)()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     469
#     470     def _set_axis(self, axis, labels):
# --> 471         self._data.set_axis(axis, labels)
#     472         self._clear_item_cache()
#     473
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    2834             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2835                              'new values have %d elements' %
# -> 2836                              (old_len, new_len))
#    2837
#    2838         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 12 elements, new values have 10 elements

# %%
#add one column as row sum
file['allPosts'] = file.sum(axis=1) 
file[1:5]
# Out:
#                                   negaTran  posiTran  mixTran  neuTran  \
# f8708568eff1535c85247b28dc126f9b        22        56        0        4
# f49956142aab2ad74decfd49a103c2f1         5        11        0        3
# f358b75c71d85c91ec0452c6114e3b15         3        16        2        0
# ec3dc451b8a811f05ace158a0d76e32e         7         0        0        2
#
#                                   PosAndNeg  MixAndPos  MixAndNeg  MixAndNeu  \
# f8708568eff1535c85247b28dc126f9b         36          4          2          0
# f49956142aab2ad74decfd49a103c2f1         10          0          0          0
# f358b75c71d85c91ec0452c6114e3b15         10          1          1          0
# ec3dc451b8a811f05ace158a0d76e32e          2          0          0          0
#
#                                   NeuAndPos  NeuAndNeg  allPosts
# f8708568eff1535c85247b28dc126f9b         20         16       160
# f49956142aab2ad74decfd49a103c2f1          9         10        48
# f358b75c71d85c91ec0452c6114e3b15          5          1        39
# ec3dc451b8a811f05ace158a0d76e32e          2         10        23

# %% [markdown]
# compute transition states probability,  we compute the pobability by dividing the transition with number of all posts

# %%
Tranprob = file.apply(lambda x: x/file.iloc[:,-1])
Tranprob['userid'] = Tranprob.index
Tranprob[1:5]
# Out:
#                                   negaTran  posiTran   mixTran   neuTran  \
# f8708568eff1535c85247b28dc126f9b  0.137500  0.350000  0.000000  0.025000
# f49956142aab2ad74decfd49a103c2f1  0.104167  0.229167  0.000000  0.062500
# f358b75c71d85c91ec0452c6114e3b15  0.076923  0.410256  0.051282  0.000000
# ec3dc451b8a811f05ace158a0d76e32e  0.304348  0.000000  0.000000  0.086957
#
#                                   PosAndNeg  MixAndPos  MixAndNeg  MixAndNeu  \
# f8708568eff1535c85247b28dc126f9b   0.225000   0.025000   0.012500        0.0
# f49956142aab2ad74decfd49a103c2f1   0.208333   0.000000   0.000000        0.0
# f358b75c71d85c91ec0452c6114e3b15   0.256410   0.025641   0.025641        0.0
# ec3dc451b8a811f05ace158a0d76e32e   0.086957   0.000000   0.000000        0.0
#
#                                   NeuAndPos  NeuAndNeg  allPosts  \
# f8708568eff1535c85247b28dc126f9b   0.125000   0.100000       1.0
# f49956142aab2ad74decfd49a103c2f1   0.187500   0.208333       1.0
# f358b75c71d85c91ec0452c6114e3b15   0.128205   0.025641       1.0
# ec3dc451b8a811f05ace158a0d76e32e   0.086957   0.434783       1.0
#
#                                                             userid
# f8708568eff1535c85247b28dc126f9b  f8708568eff1535c85247b28dc126f9b
# f49956142aab2ad74decfd49a103c2f1  f49956142aab2ad74decfd49a103c2f1
# f358b75c71d85c91ec0452c6114e3b15  f358b75c71d85c91ec0452c6114e3b15
# ec3dc451b8a811f05ace158a0d76e32e  ec3dc451b8a811f05ace158a0d76e32e

# %%
Tranprob.to_csv(path + 'newScripts/moodVector/moodVectorsData/PostsValenceTransitions(noEmp).csv')

# %% [markdown]
# correlation with all scales

# %%
allData = pd.read_csv( path + '/data/important_data/user_scale_post_time2.csv')
Var = allData[['userid','ope','con','ext','agr','neu','swl','CESD_sum']]

# %%
compare = pd.merge(Tranprob, Var, on ='userid', how = 'left')
corMatrix = compare.corr()
corMatrix.to_csv(path + 'newScripts/moodVector/moodVectorsData/PostsValenceTrancorrelationMatrix(noEmp).csv')

# %%
compare.shape
# Out:
# (74, 19)

# %%
compareFreq = pd.merge(df, Var, on ='userid', how = 'left')
corMatrix = compareFreq.corr()
corMatrix.to_csv(path + 'newScripts/moodVector/moodVectorsData/PostsValenceFreqMatrix(noEmp).csv')
corMatrix
# Out:
#                NegativePosts  PositivePosts  NeutralPosts  MixedPosts  \
# NegativePosts       1.000000       0.575563      0.545127    0.496761
# PositivePosts       0.575563       1.000000      0.394378    0.574895
# NeutralPosts        0.545127       0.394378      1.000000    0.259793
# MixedPosts          0.496761       0.574895      0.259793    1.000000
# ope                -0.137392      -0.161032     -0.092921   -0.032658
# con                -0.008357      -0.059051     -0.173541    0.045069
# ext                -0.159222       0.095809     -0.178013   -0.074525
# agr                -0.271421      -0.005838     -0.223745    0.103119
# neu                 0.193769       0.152406      0.046922    0.150321
# swl                -0.140572      -0.027483     -0.098969   -0.088840
# CESD_sum            0.157643       0.098691      0.036401    0.127829
#
#                     ope       con       ext       agr       neu       swl  \
# NegativePosts -0.137392 -0.008357 -0.159222 -0.271421  0.193769 -0.140572
# PositivePosts -0.161032 -0.059051  0.095809 -0.005838  0.152406 -0.027483
# NeutralPosts  -0.092921 -0.173541 -0.178013 -0.223745  0.046922 -0.098969
# MixedPosts    -0.032658  0.045069 -0.074525  0.103119  0.150321 -0.088840
# ope            1.000000 -0.075814  0.305311  0.017626 -0.209973 -0.078370
# con           -0.075814  1.000000  0.184559  0.151372 -0.367604  0.401755
# ext            0.305311  0.184559  1.000000  0.182808 -0.345980  0.204759
# agr            0.017626  0.151372  0.182808  1.000000 -0.277535  0.246162
# neu           -0.209973 -0.367604 -0.345980 -0.277535  1.000000 -0.402645
# swl           -0.078370  0.401755  0.204759  0.246162 -0.402645  1.000000
# CESD_sum      -0.227367 -0.402877 -0.351483 -0.193154  0.614550 -0.462403
#
#                CESD_sum
# NegativePosts  0.157643
# PositivePosts  0.098691
# NeutralPosts   0.036401
# MixedPosts     0.127829
# ope           -0.227367
# con           -0.402877
# ext           -0.351483
# agr           -0.193154
# neu            0.614550
# swl           -0.462403
# CESD_sum       1.000000

# %% [markdown]
# Now we write the valence vector as csv file
